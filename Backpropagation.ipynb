# %% [markdown]
# # **Backpropagation from scratch (using NumPy) for a simple regression problem.**

# %%
import numpy as np

# 1 Create dataset
np.random.seed(42)

X = np.random.rand(100, 1)
y = 2 * X + 3

# %%
# 2 Initialize parameters
W1 = np.random.randn(1, 4)
b1 = np.zeros((1, 4))

W2 = np.random.randn(4, 1)
b2 = np.zeros((1, 1))

learning_rate = 0.01
epochs = 1000

# %%
# 3 Activation functions
def relu(x):
    return np.maximum(0, x)

def relu_derivative(x):
    return (x > 0).astype(float)

# %%
# 4 Training loop
for epoch in range(epochs):


    Z1 = X @ W1 + b1
    A1 = relu(Z1)

    Z2 = A1 @ W2 + b2
    y_pred = Z2  # Linear output for regression


    loss = np.mean((y - y_pred) ** 2)

    # Backward Pass

    dZ2 = (y_pred - y) / len(X)
    dW2 = A1.T @ dZ2
    db2 = np.sum(dZ2, axis=0, keepdims=True)

    dA1 = dZ2 @ W2.T
    dZ1 = dA1 * relu_derivative(Z1)
    dW1 = X.T @ dZ1
    db1 = np.sum(dZ1, axis=0, keepdims=True)

    # Update
    W2 -= learning_rate * dW2
    b2 -= learning_rate * db2

    W1 -= learning_rate * dW1
    b1 -= learning_rate * db1

    if epoch % 100 == 0:
        print(f"Epoch {epoch}, Loss: {loss:.5f}")
# Out:
# Epoch 0, Loss: 15.40863
# Epoch 100, Loss: 0.01468
# Epoch 200, Loss: 0.00782
# Epoch 300, Loss: 0.00414
# Epoch 400, Loss: 0.00218
# Epoch 500, Loss: 0.00115
# Epoch 600, Loss: 0.00060
# Epoch 700, Loss: 0.00031
# Epoch 800, Loss: 0.00016
# Epoch 900, Loss: 0.00008

# %%
print("\nFinal Loss:", loss)
# Out:
# Final Loss: 4.434358458524249e-05
